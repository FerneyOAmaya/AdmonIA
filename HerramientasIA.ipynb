# %% [markdown]
# #<center>Diseño de experiencias de aprendizaje con IA para el análisis, la automatización y la toma de decisiones<center>

# %% [markdown]
# [Enlace al diseño del curso](https://juanferfranco.github.io/cursoAutoEscuelaAdEcNe2024-20/design/)

# %% [markdown]
# ##2.Herramientas de IA

# %% [markdown]
# ###2.1. Chatbot Arena
#
# [Ranking de chatbots](https://lmarena.ai/)

# %% [markdown]
# ###2.2. Google Colaboratory
# - [Breve Tutorial a Google Colaboratory incluyendo Python](https://colab.research.google.com/github/FerneyOAmaya/Competencias-Digitales/blob/master/GoogleColaboratory.ipynb)
#
# - [Guía de Python](https://colab.research.google.com/github/FerneyOAmaya/Competencias-Digitales/blob/master/0_Python.ipynb)

# %% [markdown]
# ###2.3. Aprendizaje de máquina
#
# [Tutorial K-Means](https://colab.research.google.com/github/FerneyOAmaya/IA-Educacion/blob/master/KmeansDatos.ipynb)
#
# [Árboles de decisión](https://www.youtube.com/playlist?list=PLM8wYQRetTxAl5FpMIJCcJbfZjSB0IeC_)

# %% [markdown]
# ###2.4. BERT
#
# 1. Buscar la Plataforma: Hugging Face
# 2. Registrarse
# 3. Buscar el modelo: google-bert/bert-base-cased
# 4. Probar con: The goal of life is [MASK].

# %% [markdown]
# ###2.5. Visualización con Looker Studio
#
# [Tutorial Looker Studio](https://colab.research.google.com/github/FerneyOAmaya/IA-Educacion/blob/master/Visualizacion.ipynb)
