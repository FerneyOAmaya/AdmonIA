# %% [markdown]
# #<center>Diseño de experiencias de aprendizaje con IA para el análisis, la automatización y la toma de decisiones: Sesión 2<center>

# %% [markdown]
# [Enlace al diseño del curso](https://juanferfranco.github.io/cursoAutoEscuelaAdEcNe2024-20/design/)

# %% [markdown]
# ##1. Diseño de la actividad de aprendizaje

# %% [markdown]
# ###1.1. Herramientas de apoyo
# - ChatGPT o similar
# - [Notebooklm de Google](https://notebooklm.google.com/)
# - [Perplexity](https://www.perplexity.ai/) o [ARC](https://arc.net/)

# %% [markdown]
# ###1.2. Descripción de la actividad (*Diligenciar*)
#
# 1.	Curso del 2025-1.
# 2.	Actividad y alcance.
# 3.	Impacto.
# 4.	Pertinencia.
# 5.	Tecnologías emergentes.

# %% [markdown]
# ###1.3. Cronograma desarrollo del curso (*Diligenciar*)
# Incluir una cronograma de actividades que el docente desarrollará para diseñar el curso, indicando para cada actividad:
# - Tiempo en que el estudiante realizará la actividad
# - Actividad que realizará el estudiante
# - Recurso que desarrollará el docente
# - Producto que entregará el estudiante

# %% [markdown]
# ###1.4. Hacerlo atractivo (*Diligenciar*)
#
# Presente un escenario atractivo: Presente un problema o desafío del mundo real que requiera que los estudiantes apliquen sus conocimientos. Ejemplo: "Diseñar una solución energética sustentable para una escuela local o un centro comunitario".

# %% [markdown]
# ###1.5. Motivación - (*Diligenciar - opcional*)
#
# Genere estrategias para mantener la motivación de los estudiantes a lo largo de la actividad.
#
# ¿Puede incluir elementos de ludificación?

# %% [markdown]
# ##Enlaces útiles
